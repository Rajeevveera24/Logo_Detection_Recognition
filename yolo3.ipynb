# %% [markdown]
# <a href="https://colab.research.google.com/github/arjungoel7/Logo_Detection_Recognition/blob/master/yolo3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://github.com/eriklindernoren/PyTorch-YOLOv3
# Out:
# Cloning into 'PyTorch-YOLOv3'...
# remote: Enumerating objects: 724, done.
# remote: Total 724 (delta 0), reused 0 (delta 0), pack-reused 724
# Receiving objects: 100% (724/724), 16.18 MiB | 18.06 MiB/s, done.
# Resolving deltas: 100% (411/411), done.

# %%
# !ls
# Out:
# sample_data

# %%
# %cd PyTorch-YOLOv3
# Out:
# /content/PyTorch-YOLOv3

# %%
# !sudo pip3 install -r requirements.txt

# %%
# %cd weights/
# Out:
# /content/PyTorch-YOLOv3/weights

# %%
# !cp /content/drive/My\ Drive/darknet53.conv.74 /content/PyTorch-YOLOv3/weights/

# %%
# %cd ..
# Out:
# /content/PyTorch-YOLOv3

# %%
# %cd config/
# Out:
# /content/PyTorch-YOLOv3/config

# %%
# !bash create_custom_model.sh 4

# %%
# %cd ..
# Out:
# /content/PyTorch-YOLOv3

# %%
# %cd utils/
# Out:
# /content/PyTorch-YOLOv3/utils

# %%
# !ls
# Out:
# augmentations.py  __init__.py  parse_config.py
# datasets.py	  logger.py    utils.py

# %%
# !rm logger.py
# !rm datasets.py

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dca851c4-9364-4acc-86d6-cb9049e50dba" name="files[]" multiple disabled />
#      <output id="result-dca851c4-9364-4acc-86d6-cb9049e50dba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving datasets.py to datasets.py
# Saving logger.py to logger.py

# %%
# %cd ..
# Out:
# /content/PyTorch-YOLOv3

# %%
# %cd data/custom/
# Out:
# /content/PyTorch-YOLOv3/data/custom

# %%
# !ls
# Out:
# classes.names  images  labels  test_images  train.txt  valid.txt

# %%
# !rm train.txt
# !rm valid.txt
# !rm classes.names
# !rm -rf images
# !rm -rf labels

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4bf4768d-2034-477c-a4a2-4a418a0bafe9" name="files[]" multiple disabled />
#      <output id="result-4bf4768d-2034-477c-a4a2-4a418a0bafe9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving classes.names to classes.names

# %%
# !rm classes.txt

# %%
# %cd data/custom

# %%
# !unzip images.zip
# !unzip labels.zip

# %%
# !ls

# %%
# %cd /content/PyTorch-YOLOv3
# Out:
# /content/PyTorch-YOLOv3

# %%
# !python3 train.py --model_def config/yolov3-custom.cfg --data_config config/custom.data --pretrained_weights weights/darknet53.conv.74
# Out:
# 2020-05-05 01:21:07.248227: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Namespace(batch_size=8, checkpoint_interval=1, compute_map=False, data_config='config/custom.data', epochs=100, evaluation_interval=1, gradient_accumulations=2, img_size=416, model_def='config/yolov3-custom.cfg', multiscale_training=True, n_cpu=8, pretrained_weights='weights/darknet53.conv.74')
# 2020-05-05 01:21:08.719743: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-05 01:21:08.741506: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-05 01:21:08.742156: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# ...

# %%
# %cd checkpoints/
# Out:
# /content/PyTorch-YOLOv3/checkpoints

# %%
# !ls
# Out:
# yolov3_ckpt_0.pth   yolov3_ckpt_32.pth	yolov3_ckpt_55.pth  yolov3_ckpt_78.pth
# yolov3_ckpt_10.pth  yolov3_ckpt_33.pth	yolov3_ckpt_56.pth  yolov3_ckpt_79.pth
# yolov3_ckpt_11.pth  yolov3_ckpt_34.pth	yolov3_ckpt_57.pth  yolov3_ckpt_7.pth
# yolov3_ckpt_12.pth  yolov3_ckpt_35.pth	yolov3_ckpt_58.pth  yolov3_ckpt_80.pth
# yolov3_ckpt_13.pth  yolov3_ckpt_36.pth	yolov3_ckpt_59.pth  yolov3_ckpt_81.pth
# yolov3_ckpt_14.pth  yolov3_ckpt_37.pth	yolov3_ckpt_5.pth   yolov3_ckpt_82.pth
# yolov3_ckpt_15.pth  yolov3_ckpt_38.pth	yolov3_ckpt_60.pth  yolov3_ckpt_83.pth
# yolov3_ckpt_16.pth  yolov3_ckpt_39.pth	yolov3_ckpt_61.pth  yolov3_ckpt_84.pth
# yolov3_ckpt_17.pth  yolov3_ckpt_3.pth	yolov3_ckpt_62.pth  yolov3_ckpt_85.pth
# yolov3_ckpt_18.pth  yolov3_ckpt_40.pth	yolov3_ckpt_63.pth  yolov3_ckpt_86.pth
# yolov3_ckpt_19.pth  yolov3_ckpt_41.pth	yolov3_ckpt_64.pth  yolov3_ckpt_87.pth
# yolov3_ckpt_1.pth   yolov3_ckpt_42.pth	yolov3_ckpt_65.pth  yolov3_ckpt_88.pth
# ...

# %%
# !cp yolov3_ckpt_99.pth /content/drive/My\ Drive/

# %%
# %cd data/custom/
# Out:
# /content/PyTorch-YOLOv3/data/custom

# %%
# !mkdir test_images

# %%
# %cd test_images
# Out:
# /content/PyTorch-YOLOv3/data/custom/test_images

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c0427615-1807-4288-868a-9d911f71dd91" name="files[]" multiple disabled />
#      <output id="result-c0427615-1807-4288-868a-9d911f71dd91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving images (10).jpeg to images (10).jpeg
# Saving images (11).png to images (11).png

# %%
# %cd /content/PyTorch-YOLOv3
# Out:
# /content/PyTorch-YOLOv3

# %%
# !python3 detect.py --image_folder data/custom/test_images --checkpoint_model checkpoints/yolov3_ckpt_99.pth --model_def config/yolov3-custom.cfg --class_path data/custom/classes.names --conf_thres 0.95 --nms_thres 0.4 --weights_path checkpoints/yolov3_ckpt_99.pth
# Out:
# Namespace(batch_size=1, checkpoint_model='checkpoints/yolov3_ckpt_99.pth', class_path='data/custom/classes.names', conf_thres=0.95, image_folder='data/custom/test_images', img_size=416, model_def='config/yolov3-custom.cfg', n_cpu=0, nms_thres=0.4, weights_path='checkpoints/yolov3_ckpt_99.pth')
# Traceback (most recent call last):
#   File "detect.py", line 51, in <module>
#     model.load_state_dict(torch.load(opt.weights_path))
#   File "/usr/local/lib/python3.6/dist-packages/torch/serialization.py", line 525, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.6/dist-packages/torch/serialization.py", line 212, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/usr/local/lib/python3.6/dist-packages/torch/serialization.py", line 193, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'checkpoints/yolov3_ckpt_99.pth'

# %%
# %cd output
# Out:
# /content/PyTorch-YOLOv3/output

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# 'images (10).png'  'images (22).png'  'images (34).png'  'images (46).png'
# 'images (11).png'  'images (23).png'  'images (35).png'  'images (47).png'
# 'images (12).png'  'images (24).png'  'images (36).png'  'images (48).png'
# 'images (13).png'  'images (25).png'  'images (37).png'  'images (49).png'
# 'images (14).png'  'images (26).png'  'images (38).png'  'images (4).png'
# 'images (15).png'  'images (27).png'  'images (39).png'  'images (50).png'
# 'images (16).png'  'images (28).png'  'images (3).png'	 'images (51).png'
# 'images (17).png'  'images (29).png'  'images (40).png'  'images (5).png'
# 'images (18).png'  'images (2).png'   'images (41).png'  'images (6).png'
# 'images (19).png'  'images (30).png'  'images (42).png'  'images (7).png'
# 'images (1).png'   'images (31).png'  'images (43).png'  'images (8).png'
# 'images (20).png'  'images (32).png'  'images (44).png'  'images (9).png'
# 'images (21).png'  'images (33).png'  'images (45).png'

# %%
img = cv2.imread('images (12).png')
plt.imshow(img)

# %%
img = cv2.imread('images (20).png')
plt.imshow(img)

# %%
img = cv2.imread('images (29).png')
plt.imshow(img)

# %%
# %cd ..
# Out:
# /content/PyTorch-YOLOv3

# %%
files.download('train.py')

# %%
# !rm train.py

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3f0e7a42-c735-4082-9689-d31dc6b4e5e5" name="files[]" multiple disabled />
#      <output id="result-3f0e7a42-c735-4082-9689-d31dc6b4e5e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.py to train.py

# %%
# !python3 train.py --model_def config/yolov3-custom.cfg --data_config config/custom.data --pretrained_weights weights/darknet53.conv.74
# Out:
# 2020-04-26 00:15:44.673480: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Namespace(batch_size=8, checkpoint_interval=1, compute_map=False, data_config='config/custom.data', epochs=100, evaluation_interval=1, gradient_accumulations=2, img_size=416, model_def='config/yolov3-custom.cfg', multiscale_training=True, n_cpu=8, pretrained_weights='weights/darknet53.conv.74')
# 2020-04-26 00:15:46.133187: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-26 00:15:46.166522: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 00:15:46.167089: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# ...

# %%
# %cd backup
# Out:
# /content/PyTorch-YOLOv3/backup

# %%
# !ls
# Out:
# newYolov3.weights

# %%
files.download('newYolov3.weights')
# Out:
# ----------------------------------------
# Exception happened during processing of request from ('::ffff:127.0.0.1', 57714, 0, 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/socketserver.py", line 320, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 351, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 364, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.6/socketserver.py", line 724, in __init__
#     self.handle()
#   File "/usr/lib/python3.6/http/server.py", line 418, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.6/http/server.py", line 406, in handle_one_request
#     method()
#   File "/usr/lib/python3.6/http/server.py", line 639, in do_GET
#     self.copyfile(f, self.wfile)
# ...

# %%
# !cp newYolov3.weights /content/drive/My\ Drive

# %%
# %cd ..
# Out:
# /content/PyTorch-YOLOv3

# %%
# !python3 detect.py --image_folder data/custom/test_images --model_def config/yolov3-custom.cfg --class_path data/custom/classes.names --conf_thres 0.95 --nms_thres 0.4 --weights_path backup/newYolov3.weights

# %%
# %cd data/custom/test_images/
# Out:
# /content/PyTorch-YOLOv3/data/custom/test_images

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-40d7fc90-ff41-4963-9927-952c1130d84c" name="files[]" multiple disabled />
#      <output id="result-40d7fc90-ff41-4963-9927-952c1130d84c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dropbox_img.png to dropbox_img.png

# %%
# !python3 detect.py --image_folder data/custom/test_images --model_def config/yolov3-custom.cfg --class_path data/custom/classes.names --conf_thres 0.95 --nms_thres 0.4 --weights_path /content/drive/My\ Drive/newYolov3.weights
# Out:
# Namespace(batch_size=1, checkpoint_model=None, class_path='data/custom/classes.names', conf_thres=0.95, image_folder='data/custom/test_images', img_size=416, model_def='config/yolov3-custom.cfg', n_cpu=0, nms_thres=0.4, weights_path='/content/drive/My Drive/newYolov3.weights')
#
# Performing object detection:
# 	+ Batch 0, Inference Time: 0:00:00.201705
# 	+ Batch 1, Inference Time: 0:00:00.103915
# 	+ Batch 2, Inference Time: 0:00:00.088819
#
# Saving images:
# (0) Image: 'data/custom/test_images/dropbox_img.png'
# 	+ Label: dropbox, Conf: 1.00000
# 	+ Label: paypal, Conf: 0.99369
# 	+ Label: dropbox, Conf: 0.98684
# (1) Image: 'data/custom/test_images/fb_image.JPG'
# 	+ Label: paypal, Conf: 0.99726
# 	+ Label: facebook, Conf: 0.63362
# (2) Image: 'data/custom/test_images/images (12).png'
# 	+ Label: amazon, Conf: 0.99452

# %%
# %cd output
# Out:
# /content/PyTorch-YOLOv3/output

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
#  dropbox_img.png   fb_image.png  'images (12).png'

# %%
img = cv2.imread('dropbox_img.png')
plt.imshow(img)

# %%
# !ls
# Out:
# assets	data	   LICENSE    output	   README.md	     test.py   utils
# config	detect.py  models.py  __pycache__  requirements.txt  train.py  weights
